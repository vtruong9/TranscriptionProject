# %%
import numpy as np
import gzip
import pandas as pd

# %% [markdown]
# Reference code from Mike Harms
#
# ```
# def load_pdb(pdb_file):
#
#     f = open(pdb_file,'r')
#     lines = f.readlines()
#     f.close()
#
#     all_coord = []
#     for l in lines:
#         if l[0:4] == "ATOM" and l[13:16] == "CA ":
#             coord = [float(l[(30 + i*8):(38 + i*8)]) for i in range(3)]
#             all_coord.append(coord)
#
#     return np.array(all_coord)
# ```
#
# ```
# import gzip
#
# get_line = False
# seqs = {}
# with gzip.open("files/example.fastq.gz") as f:
#     for l in f:
#         l_ascii = l.decode("ascii")
#         if l_ascii[0] == "@":
#             get_line = True
#             continue
#         if get_line:
#             try:
#                 seqs[l_ascii.strip()] += 1
#             except KeyError:
#                 seqs[l_ascii.strip()] = 1
#             get_line = False
# ```

# %%
### TEST ###
# f = open("summary38genes.csv")
# print(alphaList)

# %%
#for line in file:
#     line[xcount up][1]
#     print to existingSpreadsheet.xls

f = open("summary38genes.csv")
lines = f.readlines()
f.close()
#print(lines)

print(lines[0])
type(lines[0])

print(lines[0][0])
type(lines[0][0])

# This is pretty good progress Vi don't fuck with it anymore.
# lines is a list where each item is a string containing the previously-comma-separated row
# Out:
# "input" "reason" "matches" "symbol" "organism.shortName" "name" "length" "secondaryIdentifier" "primaryIdentifier" "class"
#
# "
# str

# %%
#for line in file:
#     line[xcount up][1]
#     print to existingSpreadsheet.xls

genlist = []

f = open("summary38genes.csv")
lines = f.readlines()


for line in lines:
    row = line.strip('\n')
    genlist.append(row)
    
f.close()

np.array(genlist)
# Out:
# array(['"input" "reason" "matches" "symbol" "organism.shortName" "name" "length" "secondaryIdentifier" "primaryIdentifier" "class"',
#        '"YMR303C" "MATCH" "1" "ADH2" "S. cerevisiae" "Alcohol DeHydrogenase" "1047" "YMR303C" "S000004918" "ORF"',
#        '"YCR045C" "MATCH" "1" "RRT12" "S. cerevisiae" "Regulator of rDNA Transcription" "1476" "YCR045C" "S000000641" "ORF"',
#        '"YLR374C" "MATCH" "1" "" "S. cerevisiae" "" "390" "YLR374C" "S000004366" "ORF"',
#        '"YML083C" "MATCH" "1" "" "S. cerevisiae" "" "1257" "YML083C" "S000004548" "ORF"',
#        '"YLL005C" "MATCH" "1" "SPO75" "S. cerevisiae" "SPOrulation" "2607" "YLL005C" "S000003928" "ORF"',
#        '"YGL205W" "MATCH" "1" "POX1" "S. cerevisiae" "" "2247" "YGL205W" "S000003173" "ORF"',
#        '"YJR128W" "MATCH" "1" "" "S. cerevisiae" "" "360" "YJR128W" "S000003889" "ORF"',
#        '"YNR062C" "MATCH" "1" "PUL3" "S. cerevisiae" "PULcherrimin" "984" "YNR062C" "S000005345" "ORF"',
# ...

# %%
# Out:
# i
# i
# 1

# %%
# Out:
# [('i', <class 'str'>), ('n', <class 'str'>), ('p', <class 'str'>), ('u', <class 'str'>), ('t', <class 'str'>), (' ', <class 'str'>), ('r', <class 'str'>), ('e', <class 'str'>), ('a', <class 'str'>), ('s', <class 'str'>), ('o', <class 'str'>), ('n', <class 'str'>), (' ', <class 'str'>), ('m', <class 'str'>), ('a', <class 'str'>), ('t', <class 'str'>), ('c', <class 'str'>), ('h', <class 'str'>), ('e', <class 'str'>), ('s', <class 'str'>), (' ', <class 'str'>), ('s', <class 'str'>), ('y', <class 'str'>), ('m', <class 'str'>), ('b', <class 'str'>), ('o', <class 'str'>), ('l', <class 'str'>), (' ', <class 'str'>), ('o', <class 'str'>), ('r', <class 'str'>), ('g', <class 'str'>), ('a', <class 'str'>), ('n', <class 'str'>), ('i', <class 'str'>), ('s', <class 'str'>), ('m', <class 'str'>), ('.', <class 'str'>), ('s', <class 'str'>), ('h', <class 'str'>), ('o', <class 'str'>), ('r', <class 'str'>), ('t', <class 'str'>), ('N', <class 'str'>), ('a', <class 'str'>), ('m', <class 'str'>), ('e', <
# ...

# %%
# Out:
# ['"', 'i', 'n', 'p', 'u', 't', '"', ' ', '"', 'r', 'e', 'a', 's', 'o', 'n', '"', ' ', '"', 'm', 'a', 't', 'c', 'h', 'e', 's', '"', ' ', '"', 's', 'y', 'm', 'b', 'o', 'l', '"', ' ', '"', 'o', 'r', 'g', 'a', 'n', 'i', 's', 'm', '.', 's', 'h', 'o', 'r', 't', 'N', 'a', 'm', 'e', '"', ' ', '"', 'n', 'a', 'm', 'e', '"', ' ', '"', 'l', 'e', 'n', 'g', 't', 'h', '"', ' ', '"', 's', 'e', 'c', 'o', 'n', 'd', 'a', 'r', 'y', 'I', 'd', 'e', 'n', 't', 'i', 'f', 'i', 'e', 'r', '"', ' ', '"', 'p', 'r', 'i', 'm', 'a', 'r', 'y', 'I', 'd', 'e', 'n', 't', 'i', 'f', 'i', 'e', 'r', '"', ' ', '"', 'c', 'l', 'a', 's', 's', '"', '\n', '"', 'Y', 'M', 'R', '3', '0', '3', 'C', '"', ' ', '"', 'M', 'A', 'T', 'C', 'H', '"', ' ', '"', '1', '"', ' ', '"', 'A', 'D', 'H', '2', '"', ' ', '"', 'S', '.', ' ', 'c', 'e', 'r', 'e', 'v', 'i', 's', 'i', 'a', 'e', '"', ' ', '"', 'A', 'l', 'c', 'o', 'h', 'o', 'l', ' ', 'D', 'e', 'H', 'y', 'd', 'r', 'o', 'g', 'e', 'n', 'a', 's', 'e', '"', ' ', '"', '1', '0', '4', '7', '"', ' ', '
# ...
